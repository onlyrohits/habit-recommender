# %%
# %run 'Plot Prep.ipynb'

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.lines
import numpy as np
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Length of session')
ax.set_ylabel('Frequency')
ax.set_zlabel('Time until results ')
ax.scatter(health_session_length,
                        health_frequency,
                        health_time_to_result,
                        s=100, c = health_color)
colors = ['#8B00FF', '#4B0082', '#0000FF', '#00FF00','#FFFF00','#FF7F00','#FF0000']
scatter1_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[0], marker = 'o')
scatter2_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[1], marker = 'o')
scatter3_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[2], marker = 'o')
scatter4_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[3], marker = 'o')
scatter5_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[4], marker = 'o')
scatter6_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[5], marker = 'o')
scatter7_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[6], marker = 'o')
ax.legend([scatter1_proxy, scatter2_proxy, scatter3_proxy, scatter4_proxy,
           scatter5_proxy, scatter6_proxy, scatter7_proxy],
          ['1', '2', '3', '4', '5', '6', '7'],
          loc='upper left')
score = np.array(health_session_length[:i]) * np.array(health_frequency[:i]) * np.array(health_time_to_result[:i]) / np.array(health_score[:i]) 
j = np.argmin(score)
x, y, _ = proj3d.proj_transform(health_session_length[j], health_frequency[j],
                                health_time_to_result[j], ax.get_proj())
ax.annotate("Best habit", xy = (x, y), xytext = (20, 40),  textcoords = 'offset points', 
            ha = 'left', va = 'bottom', arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.lines
import numpy as np
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Length of session')
ax.set_ylabel('Frequency')
ax.set_zlabel('Time until results ')
ax.scatter(health_session_length,
                        health_frequency,
                        health_time_to_result,
                        s=100, c = health_color)
colors = ['#8B00FF', '#4B0082', '#0000FF', '#00FF00','#FFFF00','#FF7F00','#FF0000']
scatter1_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[0], marker = 'o')
scatter2_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[1], marker = 'o')
scatter3_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[2], marker = 'o')
scatter4_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[3], marker = 'o')
scatter5_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[4], marker = 'o')
scatter6_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[5], marker = 'o')
scatter7_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[6], marker = 'o')
ax.legend([scatter1_proxy, scatter2_proxy, scatter3_proxy, scatter4_proxy,
           scatter5_proxy, scatter6_proxy, scatter7_proxy],
          ['1', '2', '3', '4', '5', '6', '7'],
          loc='upper left')
score = np.array(health_session_length[:i]) / np.array(health_score[:i]) 
j = np.argmin(score)
x, y, _ = proj3d.proj_transform(health_session_length[j], health_frequency[j],
                                health_time_to_result[j], ax.get_proj())
ax.annotate("Best habit", xy = (x, y), xytext = (20, 40),  textcoords = 'offset points', 
            ha = 'left', va = 'bottom', arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.lines

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Length of session')
ax.set_ylabel('Frequency')
ax.set_zlabel('Time until results ')
ax.scatter(wealth_session_length,
                        wealth_frequency,
                        wealth_time_to_result,
                        s=100, c = wealth_color)

colors = ['#8B00FF', '#4B0082', '#0000FF', '#00FF00','#FFFF00','#FF7F00','#FF0000']
scatter1_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[0], marker = 'o')
scatter2_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[1], marker = 'o')
scatter3_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[2], marker = 'o')
scatter4_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[3], marker = 'o')
scatter5_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[4], marker = 'o')
scatter6_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[5], marker = 'o')
scatter7_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[6], marker = 'o')
ax.legend([scatter1_proxy, scatter2_proxy, scatter3_proxy, scatter4_proxy,
           scatter5_proxy, scatter6_proxy, scatter7_proxy],
          ['1', '2', '3', '4', '5', '6', '7'],
          loc='upper left')

plt.show()

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.lines

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Length of session')
ax.set_ylabel('Frequency')
ax.set_zlabel('Time until results ')
ax.scatter(wisdom_session_length,
                        wisdom_frequency,
                        wisdom_time_to_result,
                        s=100, c = wisdom_color)

colors = ['#8B00FF', '#4B0082', '#0000FF', '#00FF00','#FFFF00','#FF7F00','#FF0000']
scatter1_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[0], marker = 'o')
scatter2_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[1], marker = 'o')
scatter3_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[2], marker = 'o')
scatter4_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[3], marker = 'o')
scatter5_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[4], marker = 'o')
scatter6_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[5], marker = 'o')
scatter7_proxy = matplotlib.lines.Line2D([0],[0], linestyle="none", c=colors[6], marker = 'o')
ax.legend([scatter1_proxy, scatter2_proxy, scatter3_proxy, scatter4_proxy,
           scatter5_proxy, scatter6_proxy, scatter7_proxy],
          ['1', '2', '3', '4', '5', '6', '7'],
          loc='upper left')

plt.show()
